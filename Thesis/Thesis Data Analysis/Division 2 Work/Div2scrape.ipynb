# %%
import requests

url = "https://web3.ncaa.org/aprsearch/gsrsearch"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36"
}

response = requests.get(url, headers=headers)

# %%
import os
import pandas as pd
import requests
from playwright.async_api import async_playwright

# %%
import re

def clean_filename(text):
    """Remove unsafe characters and format for filenames"""
    return re.sub(r'[\\/*?:"<>|]', "", text.strip().replace(" ", "_"))

async def main():
    os.makedirs("pdfs", exist_ok=True)

    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=False)
        page = await browser.new_page()

        await page.goto("https://web3.ncaa.org/aprsearch/asrsearch", timeout=60000)
        
        await page.wait_for_selector('select[name="sportCode"]')
        await page.select_option('select[name="sportCode"]', label="Overall")
        await page.select_option('select[name="cohortYear"]', label="2023-2024")
        await page.wait_for_timeout(1000)
        await page.locator("button:has-text('Search')").click(force=True)

        await page.wait_for_selector("table tbody tr", timeout=20000)

        header_elts = await page.locator("table thead tr th").all_inner_texts()
        headers = [h.strip() for h in header_elts] + ["PDF_URL"]

        all_rows = []
        all_pdf_links = set()
        page_num = 1

        while True:
            print(f"Scraping page {page_num}...")

            row_count = await page.locator("table tbody tr").count()

            for i in range(row_count):
                row_locator = page.locator("table tbody tr").nth(i)
                cell_count = await row_locator.locator("td").count()
                row_cells = []

                for j in range(cell_count):
                    cell_text = await row_locator.locator("td").nth(j).inner_text()
                    row_cells.append(cell_text.strip())

                pdf_cell = row_locator.locator("td").nth(cell_count - 1)
                pdf_link_locator = pdf_cell.locator("a[href*='inst2024']")
                if await pdf_link_locator.count() > 0:
                    pdf_href = await pdf_link_locator.get_attribute("href")
                    full_url = f"https://web3.ncaa.org{pdf_href}"
                    row_cells.append(full_url)
                    all_pdf_links.add((row_cells[0], full_url))
                else:
                    row_cells.append("")

                if len(row_cells) == len(headers):
                    all_rows.append(row_cells)

            next_btn = page.locator("text=Next")
            if await next_btn.count() == 0:
                break
            try:
                btn_class = await next_btn.first.get_attribute("class") or ""
            except:
                break
            if "disabled" in btn_class:
                break

            first_row_before = await page.locator("table tbody tr").nth(0).inner_text()
            await next_btn.click()
            await page.wait_for_timeout(1500)
            first_row_after = await page.locator("table tbody tr").nth(0).inner_text()

            if first_row_after == first_row_before:
                break
            page_num += 1

        df = pd.DataFrame(all_rows, columns=headers)
        df.to_csv("div2_data_2023_2024.csv", index=False)
        print(f"\n Saved {len(all_rows)} rows to div2_data_2023_2024.csv")

        await browser.close()

        downloaded = 0
        for school_name, url in all_pdf_links:
            if not url:
                continue

            filename = f"{clean_filename(school_name)}_FSR.pdf"
            path = os.path.join("pdfs", filename)

            try:
                r = requests.get(url)
                r.raise_for_status()
                with open(path, "wb") as f:
                    f.write(r.content)
                print(f"Downloaded: {filename}")
                downloaded += 1
            except Exception as e:
                print(f"Failed to download {filename}: {e}")

        print(f"Total PDFs downloaded: {downloaded}")

await main()
# Out:
# Scraping page 1...
# Scraping page 2...
# Scraping page 3...
# Scraping page 4...
# Scraping page 5...
# Scraping page 6...
# Scraping page 7...
# Scraping page 8...
# Scraping page 9...
# Scraping page 10...
# Scraping page 11...
# Scraping page 12...
# Scraping page 13...
# Scraping page 14...
# Scraping page 15...
# Scraping page 16...
# Scraping page 17...
# Scraping page 18...
# Scraping page 19...
# Scraping page 20...
# Scraping page 21...
# Scraping page 22...
# Scraping page 23...
# Scraping page 24...
# Scraping page 25...
# Scraping page 26...
# Scraping page 27...
# Scraping page 28...
# Scraping page 29...
# Scraping page 30...
# Scraping page 31...
# Scraping page 32...
#
#  Saved 303 rows to div2_data_2023_2024.csv
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/8744.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/8965.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/1071.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/241.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/11276.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/30140.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/1199.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/30051.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/205.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/103.pdf?v=1755023136420
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/743.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/9012.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/112.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/1266.pdf?v=1755023136420
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/349.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/791.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/2755.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/636.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/30181.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/1156.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/1083.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/510.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/144.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/613.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/30118.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/985.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/209.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/354.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/1023.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/30137.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/30244.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/358.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/560.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/332.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/598.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/8935.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/984.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/437.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/675.pdf?v=1755023136420
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/360.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/507.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/30240.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/766.pdf?v=1755023136420
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/246.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/1433.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/2759.pdf?v=1755023136420
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/30220.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/1376.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/30126.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/499.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/1123.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/408.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/100.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/30136.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/645.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/767.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/407.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/30149.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/8875.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/30028.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/628.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/52.pdf?v=1755023136420
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/1096.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/237.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/280.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/1097.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/9754.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/643.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/2716.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/790.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/197.pdf?v=1755023136420
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/423.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/291.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/155.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/30199.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/1460.pdf?v=1755023136420
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/2807.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/230.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/30092.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/1167.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/30152.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/30093.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/199.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/1346.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/638.pdf?v=1755023136420
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/10870.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/30127.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/350.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/30147.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/210.pdf?v=1755023136420
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/1438.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/30128.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/30174.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/422.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/30090.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/208.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/12830.pdf?v=1755023136420
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/1001.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/30124.pdf?v=1755023136420
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/30058.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/30063.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/11504.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/1116.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/413.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/30123.pdf?v=1755023136420
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/744.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/30105.pdf?v=1755023136420
# Downloaded: 2017_FSR.pdf
# Downloaded: 2017_FSR.pdf
# Failed to download 2017_FSR.pdf: 404 Client Error: Not Found for url: https://web3.ncaa.org/aprsearch/public_reports/inst2024/682.pdf?v=1755023136420
# Total PDFs downloaded: 195

# %%
#For the first page that did not load the first time

# %%
import pandas as pd
import nest_asyncio
import asyncio
from playwright.async_api import async_playwright

nest_asyncio.apply()

async def fetch_div2_asr_first_page(csv_path="div2_asr_2023_2024_first_page_with_pdfs.csv"):
    rows = []
    pdf_links = {}

    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=False)
        page = await browser.new_page()

        await page.goto("https://web3.ncaa.org/aprsearch/asrsearch", timeout=60000)

        await page.wait_for_selector('select[name="sportCode"]', timeout=30000)
        await page.wait_for_selector('select[name="cohortYear"]', timeout=30000)

        await page.select_option('select[name="sportCode"]', label="Overall")
        await page.select_option('select[name="cohortYear"]', label="2023-2024")

        await page.wait_for_timeout(1000)
        await page.click("button:has-text('Search')", force=True)

        await page.wait_for_selector("table tbody tr", timeout=20000)
        await page.wait_for_timeout(2000)

        row_count = await page.locator("table tbody tr").count()

        for i in range(row_count):
            row = page.locator("table tbody tr").nth(i)
            cells = row.locator("td")
            cell_texts = []
            for j in range(await cells.count()):
                cell_text = await cells.nth(j).inner_text()
                cell_texts.append(cell_text.strip())

            pdf_link_locator = cells.nth(-1).locator("a[href*='inst2024']")
            if await pdf_link_locator.count() > 0:
                href = await pdf_link_locator.get_attribute("href")
                full_url = f"https://web3.ncaa.org{href}"
            else:
                full_url = ""

            cell_texts.append(full_url)
            rows.append(cell_texts)

        await browser.close()

    headers = [
        "Cohort Year", "School", "Conference", "Sport", "State", 
        "ASR", "FGR", "ASR Report", "FGR Report", "PDF_URL"
    ]

    df = pd.DataFrame(rows, columns=headers)
    df.to_csv(csv_path, index=False)
    print(f"Saved to {csv_path}")

await fetch_div2_asr_first_page()
# Out:
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[8], line 61
#      58     df.to_csv(csv_path, index=False)
#      59     print(f"Saved to {csv_path}")
# ---> 61 await fetch_div2_asr_first_page()
#
# Cell In[8], line 13, in fetch_div2_asr_first_page(csv_path)
#      10 pdf_links = {}
#      12 async with async_playwright() as p:
# ---> 13     browser = await p.chromium.launch(headless=False)
#      14     page = await browser.new_page()
#      16     await page.goto("https://web3.ncaa.org/aprsearch/asrsearch", timeout=60000)
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/playwright/async_api/_generated.py:14398, in BrowserType.launch(self, executable_path, channel, args, ignore_default_args, handle_sigint, handle_sigterm, handle_sighup, timeout, env, headless, devtools, proxy, downloads_path, slow_mo, traces_dir, chromium_sandbox, firefox_user_prefs)
#   14283 async def launch(
#   14284     self,
#   14285     *,
#    (...)
#   14306     ] = None
#   14307 ) -> "Browser":
#   14308     """BrowserType.launch
#   14309
#   14310     Returns the browser instance.
#    (...)
#   14394     Browser
#   14395     """
#   14397     return mapping.from_impl(
# > 14398         await self._impl_obj.launch(
#   14399             executablePath=executable_path,
#   14400             channel=channel,
#   14401             args=mapping.to_impl(args),
#   14402             ignoreDefaultArgs=mapping.to_impl(ignore_default_args),
#   14403             handleSIGINT=handle_sigint,
#   14404             handleSIGTERM=handle_sigterm,
#   14405             handleSIGHUP=handle_sighup,
#   14406             timeout=timeout,
#   14407             env=mapping.to_impl(env),
#   14408             headless=headless,
#   14409             devtools=devtools,
#   14410             proxy=proxy,
#   14411             downloadsPath=downloads_path,
#   14412             slowMo=slow_mo,
#   14413             tracesDir=traces_dir,
#   14414             chromiumSandbox=chromium_sandbox,
#   14415             firefoxUserPrefs=mapping.to_impl(firefox_user_prefs),
#   14416         )
#   14417     )
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/playwright/_impl/_browser_type.py:95, in BrowserType.launch(self, executablePath, channel, args, ignoreDefaultArgs, handleSIGINT, handleSIGTERM, handleSIGHUP, timeout, env, headless, devtools, proxy, downloadsPath, slowMo, tracesDir, chromiumSandbox, firefoxUserPrefs)
#      92 params = locals_to_params(locals())
#      93 normalize_launch_params(params)
#      94 browser = cast(
# ---> 95     Browser, from_channel(await self._channel.send("launch", params))
#      96 )
#      97 self._did_launch_browser(browser)
#      98 return browser
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/playwright/_impl/_connection.py:59, in Channel.send(self, method, params)
#      58 async def send(self, method: str, params: Dict = None) -> Any:
# ---> 59     return await self._connection.wrap_api_call(
#      60         lambda: self.inner_send(method, params, False)
#      61     )
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/playwright/_impl/_connection.py:518, in Connection.wrap_api_call(self, cb, is_internal)
#     516 self._api_zone.set(parsed_st)
#     517 try:
# --> 518     return await cb()
#     519 except Exception as error:
#     520     raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/playwright/_impl/_connection.py:88, in Channel.inner_send(self, method, params, return_as_dict)
#      84     raise error
#      85 callback = self._connection._send_message_to_server(
#      86     self._object, method, _filter_none(params)
#      87 )
# ---> 88 done, _ = await asyncio.wait(
#      89     {
#      90         self._connection._transport.on_error_future,
#      91         callback.future,
#      92     },
#      93     return_when=asyncio.FIRST_COMPLETED,
#      94 )
#      95 if not callback.future.done():
#      96     callback.future.cancel()
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/asyncio/tasks.py:464, in wait(fs, timeout, return_when)
#     461     raise TypeError("Passing coroutines is forbidden, use tasks explicitly.")
#     463 loop = events.get_running_loop()
# --> 464 return await _wait(fs, timeout, return_when, loop)
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/asyncio/tasks.py:550, in _wait(fs, timeout, return_when, loop)
#     547     f.add_done_callback(_on_completion)
#     549 try:
# --> 550     await waiter
#     551 finally:
#     552     if timeout_handle is not None:
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/asyncio/futures.py:291, in Future.__await__(self)
#     289 if not self.done():
#     290     self._asyncio_future_blocking = True
# --> 291     yield self  # This tells Task to wait for completion.
#     292 if not self.done():
#     293     raise RuntimeError("await wasn't used with future")
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/asyncio/tasks.py:385, in Task.__wakeup(self, future)
#     383 def __wakeup(self, future):
#     384     try:
# --> 385         future.result()
#     386     except BaseException as exc:
#     387         # This may also be a cancellation.
#     388         self.__step(exc)
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/asyncio/futures.py:198, in Future.result(self)
#     196 if self._state == _CANCELLED:
#     197     exc = self._make_cancelled_error()
# --> 198     raise exc
#     199 if self._state != _FINISHED:
#     200     raise exceptions.InvalidStateError('Result is not ready.')
#
# CancelledError:
